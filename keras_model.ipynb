# %% [markdown]
# This notebook will showcase the development and implementation of a deep learning convolutional neural network to
# solve a the facial expression classification problem.

# %% [markdown]
# # Downloading & Exploring Dataset

# %% [markdown]
# This model follows the tensorflow classifier tutorial (https://www.tensorflow.org/tutorials/images/classification)

# %% [markdown]
# This model will use a dataset of 25616 facial expression images that are for training, and 6269 images for validation. There are five subdirectories, eahc one being linked to a class.

# %% [markdown]
# Here is a breakdown of the facial expressions directory and its subdirectories:
#
# ```
# facial_expressions/
#   train/
#     anger/
#     disgust/
#     fear/
#     happiness/
#     neutral
#     sadness/
#     surprise/
#   validate/
#     anger/
#     disgust/
#     fear/
#     hapiness/
#     neutral
#     sadness/
#     surprise/
# ```

# %% [markdown]
# Imports:

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pathlib

from tensorflow import keras
from keras import layers
from keras.models import Sequential

from sklearn.datasets import make_classification
from sklearn.preprocessing import label_binarize

# %% [markdown]
# Download the data:

# %%
# dataset_url = "http://storage.googleapis.com/cp468-group1-dataset2/facial_expressions_shortened.zip"
dataset_url = "https://storage.googleapis.com/cp468-group-1/facial_expressions.zip"
data_dir = tf.keras.utils.get_file(origin=dataset_url, extract=True, archive_format='zip')
data_dir = pathlib.Path(data_dir).with_suffix('')

# %% [markdown]
# Explore the data:

# %%
extracted_dir = pathlib.Path(data_dir).parent / 'facial_expressions'

training_dir = extracted_dir / 'train'
validation_dir = extracted_dir / 'validation'

def count_images(directory):
  image_count = len(list(directory.glob('*/*.jpg')))
  return image_count

print(f"Training Dataset Image Count: {count_images(training_dir)}")
print(f"Validation Dataset Image Count: {count_images(validation_dir)}")
# Out:
# Training Dataset Image Count: 26369
# Validation Dataset Image Count: 9518

# %% [markdown]
# Create a dataset:

# %%
IMG_HEIGHT = 48
IMG_WIDTH = 48
batch_size = 32

train_dataset = tf.keras.utils.image_dataset_from_directory(
  training_dir,
  seed = 468,
  image_size = (IMG_HEIGHT, IMG_WIDTH),
  batch_size = batch_size)
  #batch_size = count_images(training_dir))

validate_dataset = tf.keras.utils.image_dataset_from_directory(
  validation_dir,
  seed = 468,
  image_size = (IMG_HEIGHT, IMG_WIDTH),
  batch_size = batch_size)
  #batch_size = count_images(validation_dir))

class_names = train_dataset.class_names
print(class_names)
# Out:
# Found 26369 files belonging to 7 classes.
# Found 9518 files belonging to 7 classes.
# ['anger', 'disgust', 'fear', 'happiness', 'neutral', 'sadness', 'surprise']

# %% [markdown]
# Visualize the dataset:

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(18):
    ax = plt.subplot(6, 6, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# Configure dataset for performance:

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
validate_dataset = validate_dataset.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# Standardize the data:

# %%
normalization_layer = layers.Rescaling(1./255)

normalized_dataset = train_dataset.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_dataset))
first_image = image_batch[0]

print(np.min(first_image), np.max(first_image))
# Out:
# 0.16470589 0.9490197

# %% [markdown]
# Create and compile the model:

# %%
model = Sequential([
  layers.Rescaling(1./255, input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(128, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(len(class_names), name="outputs")
])

model.compile(optimizer='adam',
              loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
              metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling_3 (Rescaling)              │ (None, 48, 48, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 48, 48, 16)          │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 24, 24, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 24, 24, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 12, 12, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 12, 12, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 6, 6, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 6, 6, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 3, 3, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 3, 3, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 1152)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ outputs (Dense)                      │ (None, 7)                   │             903 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 245,927 (960.65 KB)
#  Trainable params: 245,927 (960.65 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Training the model:

# %%
epochs = 10

history = model.fit(
  train_dataset,
  validation_data = validate_dataset,
  epochs = epochs
)
# Out:
# Epoch 1/10
# 825/825 ━━━━━━━━━━━━━━━━━━━━ 106s 126ms/step - accuracy: 0.2904 - loss: 1.7111 - val_accuracy: 0.2905 - val_loss: 1.8709
# Epoch 2/10
# 825/825 ━━━━━━━━━━━━━━━━━━━━ 130s 112ms/step - accuracy: 0.4451 - loss: 1.4111 - val_accuracy: 0.3568 - val_loss: 1.8335
# Epoch 3/10
# 825/825 ━━━━━━━━━━━━━━━━━━━━ 91s 110ms/step - accuracy: 0.4976 - loss: 1.2983 - val_accuracy: 0.4010 - val_loss: 1.7091
# Epoch 4/10
# 825/825 ━━━━━━━━━━━━━━━━━━━━ 87s 106ms/step - accuracy: 0.5400 - loss: 1.1901 - val_accuracy: 0.4748 - val_loss: 1.4116
# Epoch 5/10
# 825/825 ━━━━━━━━━━━━━━━━━━━━ 141s 105ms/step - accuracy: 0.5628 - loss: 1.1229 - val_accuracy: 0.4387 - val_loss: 1.6141
# Epoch 6/10
# 825/825 ━━━━━━━━━━━━━━━━━━━━ 87s 105ms/step - accuracy: 0.5948 - loss: 1.0658 - val_accuracy: 0.4993 - val_loss: 1.4503
# Epoch 7/10
# 825/825 ━━━━━━━━━━━━━━━━━━━━ 88s 106ms/step - accuracy: 0.6159 - loss: 1.0003 - val_accuracy: 0.5132 - val_loss: 1.4667
# Epoch 8/10
# 825/825 ━━━━━━━━━━━━━━━━━━━━ 142s 106ms/step - accuracy: 0.6427 - loss: 0.9373 - val_accuracy: 0.5319 - val_loss: 1.3539
# Epoch 9/10
# 825/825 ━━━━━━━━━━━━━━━━━━━━ 86s 105ms/step - accuracy: 0.6694 - loss: 0.8617 - val_accuracy: 0.5221 - val_loss: 1.4403
# Epoch 10/10
# 825/825 ━━━━━━━━━━━━━━━━━━━━ 87s 106ms/step - accuracy: 0.6871 - loss: 0.8184 - val_accuracy: 0.4804 - val_loss: 1.7075

# %% [markdown]
# Data visualization:

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# Predict on new data:

# %%
testset_url = "https://storage.googleapis.com/cp468-group1-dataset2/facial_expressions_shortened.zip"
test_data_dir = tf.keras.utils.get_file(origin=testset_url, extract=True, archive_format='zip')
test_data_dir = pathlib.Path(test_data_dir).with_suffix('')

testing_dir = pathlib.Path(test_data_dir).parent / 'facial_expressions_shortened' / 'test_faces'
image_count = len(list(testing_dir.glob('*/*.png')))

print(f"Training Dataset Image Count: {image_count}")

testing_dataset = tf.keras.utils.image_dataset_from_directory(
  testing_dir,
  image_size = (IMG_HEIGHT, IMG_WIDTH),
  batch_size = batch_size)

scores = []

plt.rcParams.update({'font.size': 8})
plt.figure(figsize=(15, 15))

for images, labels in testing_dataset.take(1):

  for i in range(9):

    predictions = model.predict(images)
    scores.append(tf.nn.softmax(predictions[i]))

    prediction_text = "Expected: {}\nModel Predicts {} with {:.2f}% confidence.".format(class_names[labels[i]], class_names[np.argmax(scores[i])], 100* np.max(scores[i]))

    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(prediction_text)
    plt.axis("off")
# Out:
# Training Dataset Image Count: 0
# Found 7178 files belonging to 7 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
